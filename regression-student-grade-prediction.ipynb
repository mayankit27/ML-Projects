# %% [markdown]
# import necessary packages

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# load data

# %%
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")

# %% [markdown]
# explore the data

# %%
print(data.info())
print(data.head())

# %% [markdown]
# clean and preprocess the data

# %%
print(data.isnull().sum())
#there is only one thing which is not available is famil_education_level but as we know it is not important to predict the grades, so we are not hoing to do anuthing

# %% [markdown]
# select features and target data

# %%
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]
print(x)
print("\n\n\n")
print(y)

# %% [markdown]
# split the data into training and testing datasets

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# choose a model and fit(or train) the model by giving training data

# %%
model=LinearRegression()
model.fit(x_train,y_train)

# %% [markdown]
# prediction by model and evaulation

# %%
y_pred=model.predict(x_test)
print(y_test)
print("\n\n\n")
print(y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mse)
print(r2)

# %% [markdown]
# Student Grade Prediction using LinearRegression

# %%
#Step-1:- Import Necessary Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess the data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which feature will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Create and Train the model
model=LinearRegression()
model.fit(x_train,y_train)
print("\nModel:- \n",model)

#Step-7:- Test the model
y_pred=model.predict(x_test)
print("\nActual Data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-8:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_pred,y_test)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_pred,y_test)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction Using Polynomial Regression

# %%
#Step-1:- Import  Necessary Library
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which feature will be choosed as input feature and which one as output fetaure
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Apply Polynomial Features on x_train and x_test,
#so that by applying these features on Linear Regression, 
#we could make it a Polynomial Regression
poly=PolynomialFeatures(degree=2)
x_poly_train=poly.fit_transform(x_train)
x_poly_test=poly.transform(x_test)

#Step-7:- Create and Train the Model
poly_model=LinearRegression()
poly_model.fit(x_poly_train,y_train)
print("\nModel:- \n",poly_model)

#Step-8:- Test the Model
y_pred=poly_model.predict(x_poly_test)
print("\nActual Data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-9:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_pred,y_test)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_pred,y_test)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction using Decision Tree Regressor

# %%
#Step-1:- Import Necessary Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which fetaures will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into Training and Testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Create and Train the model
dt_model=DecisionTreeRegressor(max_depth=3,random_state=42)
dt_model.fit(x_train,y_train)
print("\nModel:- \n",dt_model)

#Step-7:- Test the model
y_pred=model.predict(x_test)
print("\nActual Data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-8:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_pred,y_test)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_pred,y_test)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction using KNN Regressor

# %%
#Step-1:- Import Necessary Library
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score


#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which fetaures will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into Training and Testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Create and Train the Model
knn_model=KNeighborsRegressor(n_neighbors=5)
knn_model.fit(x_train,y_train)
print("\nModel:- \n",knn_model)

#Step-7:- Test the model
y_pred=knn_model.predict(x_test)
print("\nActual data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-8:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_test,y_pred)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_test,y_pred)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction using Random Forest Regressor

# %%
#Step-1:- Import Necessary Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which fetaures will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:-Split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Create and Train the model
rf_model=RandomForestRegressor(n_estimators=3,random_state=42)
rf_model.fit(x_train,y_train)
print("\nModel:- \n",rf_model)

#Step-7:- Test the model
y_pred=rf_model.predict(x_test)
print("\nActual data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-8:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_test,y_pred)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_test,y_pred)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction using SVM Regressor

# %%
#Step-1:- import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which fetaures will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Feature Scaling(important for svm)
scaler_x=StandardScaler()
scaler_y=StandardScaler()
x_train_scaled=scaler_x.fit_transform(x_train)
x_test_scaled=scaler_x.transform(x_test)

y_train_scaled=scaler_y.fit_transform(y_train.values.reshape(-1,1)).ravel()

#Step-7:- Create and train the model
svm_model=SVR(kernel="rbf",C=100,gamma=0.1,epsilon=0.1)
svm_model.fit(x_train_scaled,y_train_scaled)
print("\nModel:- \n",svm_model)

#Step-8:- Test the model
y_pred_scaled=svm_model.predict(x_test_scaled)
y_pred=scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).ravel()
print("\nActual data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-9:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_test,y_pred)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_test,y_pred)
print("\nR2 Score:- \n",r2_score)

# %% [markdown]
# Student Grade Prediction using Gradient Boosting

# %%
#Step-1:- Import Necessary Library
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegres
from sklearn.metrics import mean_squared_error,r2_score

#Step-2:- Load and Explore the dataset
data=pd.read_csv("/kaggle/input/students-grading-dataset/Students Performance Dataset.csv")
print(data.head())
print("\n\n\n\n")
print(data.info())
print("\n\n\n\n")
print(data.isnull().sum())
print("\n\n\n\n")

#Step-3:- Clean and Preprocess data
data=data.drop("Parent_Education_Level",axis=1)

#Step-4:- Select which fetaures will be choosed as input feature and which one as output feature
features=["Midterm_Score","Assignments_Avg","Quizzes_Avg","Participation_Score","Projects_Score","Total_Score","Study_Hours_per_Week"]
x=data[features]
y=data["Final_Score"]

#Step-5:- Split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Step-6:- Create and Train the model
gb_model=GradientBoosting()
gb_model.fit(x_train,y_train)
print("\nModel:- \n",gb_model)

#Step-8:- Test the model
y_pred=gb_model.predict(x_test)
print("\nActual data:- \n",y_test)
print("\nPredicted Data:- \n",y_pred)

#Step-9:- Calculate Mean Square Error and R2 Score
mse=mean_squared_error(y_test,y_pred)
print("\nMSE:- \n",mse)
r2_score=r2_score(y_test,y_pred)
print("\nR2 Score:- \n",r2_score)
